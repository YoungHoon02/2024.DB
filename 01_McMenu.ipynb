# %% [markdown]
# <a href="https://colab.research.google.com/github/YoungHoon02/2024.DB/blob/main/01_McMenu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3
data = pd.read_csv('./menu.csv')
conn = sqlite3.connect('McDonalds.db')
data.to_sql('MCDONALDS_NUTRITION', conn)

# %%
df = pd.read_sql("SELECT * FROM MCDONALDS_NUTRITION", conn)
df.head()
# Out:
#    index   Category                              Item    Serving Size  \
# 0      0  Breakfast                      Egg McMuffin  4.8 oz (136 g)
# 1      1  Breakfast                 Egg White Delight  4.8 oz (135 g)
# 2      2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)
# 3      3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)
# 4      4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)
#
#    Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 0       300                120       13.0                         20
# 1       250                 70        8.0                         12
# 2       370                200       23.0                         35
# 3       450                250       28.0                         43
# 4       400                210       23.0                         35
#
#    Saturated Fat  Saturated Fat (% Daily Value)  ...  Carbohydrates  \
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# 범주형 스캐터플롯
plot = sns.swarmplot(x="Category", y="Sodium", data=df)
plt.setp(plot.get_xticklabels(), rotation=70)
plt.title('Sodium Content')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 48.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 72.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 14.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 17.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df['Sodium'].describe()
# Out:
# count     260.000000
# mean      495.750000
# std       577.026323
# min         0.000000
# 25%       107.500000
# 50%       190.000000
# 75%       865.000000
# max      3600.000000
# Name: Sodium, dtype: float64

# %%
df['Sodium'].idxmax()
# Out:
# 82

# %%
df.at[82, 'Item']
# Out:
# 'Chicken McNuggets (40 piece)'

# %%
plot = sns.jointplot(x='Protein', y='Total Fat', data=df)
plt.show()

# %%
plot = sns.set_style("whitegrid")
ax = sns.boxplot(x=df['Sugars'])
plt.show()
